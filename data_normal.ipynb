# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import font_manager, rc

font_path = "C:/Users/INYUP/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

df = pd.read_excel('./xlsx_/029_df.xlsx')
df.hist(bins = 50, figsize = (20,15))
plt.show()

# %%
def min_max_mormalize(lst):
    normalized = []
    for value in lst:
        normalized_num = (value-min(lst)) / (max(lst)-min(lst))
        normalized.append(normalized_num)
    return normalized

# %%
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dong     424 non-null    object
#  1   highway  424 non-null    float64
#  2   ffnc     424 non-null    int64
#  3   ffc      424 non-null    int64
#  4   nfnc     424 non-null    int64
#  5   nfc      424 non-null    int64
#  6   fsnc     424 non-null    int64
#  7   fsc      424 non-null    int64
#  8   nsnc     424 non-null    int64
#  9   nsc      424 non-null    int64
#  10  총생활인구수   424 non-null    float64
# dtypes: float64(2), int64(8), object(1)
# memory usage: 36.6+ KB

# %%
hw = df['highway']
hw = min_max_mormalize(hw)
df['highway'] = hw

# %%
ffnc = df['ffnc']
ffnc = min_max_mormalize(ffnc)
df['ffnc'] = ffnc

# %%
nfnc = df['nfnc']
nfnc = min_max_mormalize(nfnc)
df['nfnc'] = nfnc

# %%
ffc = df['ffc']
ffc = min_max_mormalize(ffc)
df['ffc'] = ffc

# %%
nfc = df['nfc']
nfc = min_max_mormalize(nfc)
df['nfc'] = nfc

# %%
fsnc = df['fsnc']
fsnc = min_max_mormalize(fsnc)
df['fsnc'] = fsnc

# %%
fsc = df['fsc']
fsc = min_max_mormalize(fsc)
df['fsc'] = fsc

# %%
nsnc = df['nsnc']
nsnc = min_max_mormalize(nsnc)
df['nsnc'] = nsnc

# %%
nsc = df['nsc']
nsc = min_max_mormalize(nsc)
df['nsc'] = nsc

# %%
df.head()
# Out:
#    dong  highway      ffnc       ffc  nfnc  nfc      fsnc       fsc  nsnc  \
# 0  가락1동      0.0  0.225806  0.000000  0.00  0.0  0.164634  0.000000  0.02
# 1  가락2동      0.0  0.161290  0.166667  0.00  0.0  0.024390  0.016260  0.08
# 2  가락본동      0.0  0.032258  0.000000  0.00  0.0  0.146341  0.154472  0.04
# 3  가리봉동      0.0  0.032258  0.000000  0.05  0.0  0.006098  0.000000  0.74
# 4   가산동      0.0  1.000000  0.000000  0.20  1.0  1.000000  0.065041  0.86
#
#         nsc        총생활인구수
# 0  0.000000  25049.834033
# 1  0.000000  24935.653890
# 2  0.260870  33157.590517
# 3  0.000000  11048.837409
# 4  0.913043  40838.242876

# %%
총생활인구수 = df['총생활인구수']
총생활인구수 = min_max_mormalize(총생활인구수)
df['총생활인구수'] = 총생활인구수

# %%
df.head()
# Out:
#    dong  highway      ffnc       ffc  nfnc  nfc      fsnc       fsc  nsnc  \
# 0  가락1동      0.0  0.225806  0.000000  0.00  0.0  0.164634  0.000000  0.02
# 1  가락2동      0.0  0.161290  0.166667  0.00  0.0  0.024390  0.016260  0.08
# 2  가락본동      0.0  0.032258  0.000000  0.00  0.0  0.146341  0.154472  0.04
# 3  가리봉동      0.0  0.032258  0.000000  0.05  0.0  0.006098  0.000000  0.74
# 4   가산동      0.0  1.000000  0.000000  0.20  1.0  1.000000  0.065041  0.86
#
#         nsc    총생활인구수
# 0  0.000000  0.322362
# 1  0.000000  0.320622
# 2  0.260870  0.445918
# 3  0.000000  0.108998
# 4  0.913043  0.562965

# %%
df.to_excel('./xlsx_/029_df1.xlsx', index=False)

# %%
df1 = pd.read_excel('./xlsx_/9218_df.xlsx')
df1 = df1.fillna(0)
df1 = df1.drop(columns=['Unnamed: 0'])
hw = df1['highway']
hw = min_max_mormalize(hw)
df1['highway'] = hw
ffnc = df1['ffnc']
ffnc = min_max_mormalize(ffnc)
df1['ffnc'] = ffnc
nfnc = df1['nfnc']
nfnc = min_max_mormalize(nfnc)
df1['nfnc'] = nfnc
ffc = df1['ffc']
ffc = min_max_mormalize(ffc)
df1['ffc'] = ffc
nfc = df1['nfc']
nfc = min_max_mormalize(nfc)
df1['nfc'] = nfc
fsnc = df1['fsnc']
fsnc = min_max_mormalize(fsnc)
df1['fsnc'] = fsnc
fsc = df1['fsc']
fsc = min_max_mormalize(fsc)
df1['fsc'] = fsc
nsnc = df1['nsnc']
nsnc = min_max_mormalize(nsnc)
df1['nsnc'] = nsnc
nsc = df1['nsc']
nsc = min_max_mormalize(nsc)
df1['nsc'] = nsc
총생활인구수 = df1['총생활인구수']
총생활인구수 = min_max_mormalize(총생활인구수)
df1['총생활인구수'] = 총생활인구수
df1.to_excel('./xlsx_/9218_df1.xlsx', index=False)

# %%
df2 = pd.read_excel('./xlsx_/18224_df.xlsx')
df2 = df2.fillna(0)
df2 = df2.drop(columns=['Unnamed: 0'])
hw = df2['highway']
hw = min_max_mormalize(hw)
df2['highway'] = hw
ffnc = df2['ffnc']
ffnc = min_max_mormalize(ffnc)
df2['ffnc'] = ffnc
nfnc = df2['nfnc']
nfnc = min_max_mormalize(nfnc)
df2['nfnc'] = nfnc
ffc = df2['ffc']
ffc = min_max_mormalize(ffc)
df2['ffc'] = ffc
nfc = df2['nfc']
nfc = min_max_mormalize(nfc)
df2['nfc'] = nfc
fsnc = df2['fsnc']
fsnc = min_max_mormalize(fsnc)
df2['fsnc'] = fsnc
fsc = df2['fsc']
fsc = min_max_mormalize(fsc)
df2['fsc'] = fsc
nsnc = df2['nsnc']
nsnc = min_max_mormalize(nsnc)
df2['nsnc'] = nsnc
nsc = df2['nsc']
nsc = min_max_mormalize(nsc)
df2['nsc'] = nsc
총생활인구수 = df2['총생활인구수']
총생활인구수 = min_max_mormalize(총생활인구수)
df2['총생활인구수'] = 총생활인구수
df2.to_excel('./xlsx_/18224_df1.xlsx', index=False)

# %%
df5 = pd.read_excel('./xlsx_/f_029df.xlsx')

# %%
df5.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  dong           X          Y  highway      ffnc  \
# 0           0             0  가락1동  127.108235  37.495329      0.0  0.225806
# 1           1             1  가락2동  127.130643  37.495860      0.0  0.161290
# 2           2             2  가락본동  127.121640  37.497217      0.0  0.032258
# 3           3             3  가리봉동  126.888257  37.482555      0.0  0.032258
# 4           4             4   가산동  126.884341  37.476835      0.0  1.000000
#
#         ffc  nfnc  nfc  ...       nsc    총생활인구수     affnc      affc     anfnc  \
# 0  0.000000  0.00  0.0  ...  0.000000  0.322362  0.067940  0.014937  0.048585
# 1  0.166667  0.00  0.0  ...  0.000000  0.320622  0.038710  0.033333  0.010000
# 2  0.000000  0.00  0.0  ...  0.260870  0.445918  0.045161  0.033333  0.010000
# 3  0.000000  0.05  0.0  ...  0.000000  0.108998  0.283871  0.000000  0.080000
# 4  0.000000  0.20  1.0  ...  0.913043  0.562965  0.335484  0.000000  0.120000
#
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    424 non-null    int64
#  1   Unnamed: 0.1  424 non-null    int64
#  2   dong          424 non-null    object
#  3   X             424 non-null    float64
#  4   Y             424 non-null    float64
#  5   highway       424 non-null    float64
#  6   ffnc          424 non-null    float64
#  7   ffc           424 non-null    float64
#  8   nfnc          424 non-null    float64
#  9   nfc           424 non-null    float64
#  10  fsnc          424 non-null    float64
#  11  fsc           424 non-null    float64
#  12  nsnc          424 non-null    float64
#  13  nsc           424 non-null    float64
#  14  총생활인구수        424 non-null    float64
#  15  affnc         424 non-null    float64
#  16  affc          424 non-null    float64
# ...

# %%
df5.index
# Out:
# RangeIndex(start=0, stop=424, step=1)

# %%
df = pd.read_excel('./xlsx_/f_029df.xlsx')
df = df.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'highway','X','Y'])

df.set_index('dong')
# Out:
#           ffnc       ffc  nfnc       nfc      fsnc       fsc  nsnc       nsc  \
# dong
# 가락1동  0.225806  0.000000  0.00  0.000000  0.164634  0.000000  0.02  0.000000
# 가락2동  0.161290  0.166667  0.00  0.000000  0.024390  0.016260  0.08  0.000000
# 가락본동  0.032258  0.000000  0.00  0.000000  0.146341  0.154472  0.04  0.260870
# 가리봉동  0.032258  0.000000  0.05  0.000000  0.006098  0.000000  0.74  0.000000
# 가산동   1.000000  0.000000  0.20  1.000000  1.000000  0.065041  0.86  0.913043
# ...        ...       ...   ...       ...       ...       ...   ...       ...
# 효창동   0.000000  0.000000  0.00  0.000000  0.073171  0.056911  0.00  0.086957
# 후암동   0.000000  0.000000  0.00  0.000000  0.030488  0.000000  0.00  0.043478
# 휘경1동  0.000000  0.000000  0.00  0.000000  0.042683  0.024390  0.00  1.000000
# 휘경2동  0.096774  0.166667  0.10  0.166667  0.030488  0.073171  0.04  0.173913
# 흑석동   0.032258  0.166667  0.05  0.000000  0.079268  0.024390  0.06  0.434783
#
# ...

# %%
mo
